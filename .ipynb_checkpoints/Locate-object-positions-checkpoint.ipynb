# %% [markdown]
# # Image segmentation

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
def open_img(img_path):
    img = cv2.imread(img_path)
    
    (left, upper, right, lower) = (572, 271, 1330, 940)
    img_cropped = img[upper:lower, left:right]
    
    return img_cropped

# %%
image_no = 3
bg = open_img("img_raw/bg.png")
img1 = open_img(f"img_raw/{image_no}.png")

bg_gray = cv2.cvtColor(bg, cv2.COLOR_BGR2GRAY)
img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# %%
img2 = open_img(f"img_probe/2.png")

# %%
# cv2.imshow('bg',bg)
# cv2.imshow('1',img1)
# cv2.imshow('2',img2)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
def segmentation(image_no, in_folder, out_folder):
    img_path = f"{in_folder}/{image_no}.png"
    img1 = open_img(img_path)
    
    img1_sub = cv2.subtract(img1, bg)
    img1_gray = cv2.cvtColor(img1_sub, cv2.COLOR_BGR2GRAY)
    ret,thresh1 = cv2.threshold(img1_gray,5,255,cv2.THRESH_BINARY)

    kernel = np.ones((3,3),np.uint8)
    erosion = cv2.erode(thresh1,kernel,iterations = 2)
    dilation = cv2.dilate(erosion,kernel,iterations = 2)
    
    img1_masked = cv2.bitwise_and(img1, img1, mask=dilation)
    cv2.imshow('ee', img1_masked)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

    a = []
    nrows = 15
    ncols = 17

    size = 40
    w_start = 35
    h_start = 31

    y_start = h_start
    for i in range(nrows):
        if(i%2==0):
            y_end = y_start + size
        elif(i%2==1):
            y_end = y_start + (size+1)

        img_row = []
        x_start = w_start
        for j in range(ncols):
            if(j%2==0):
                x_end = x_start + (size+1)
            elif(j%2==1):
                x_end = x_start + size

            img_to_write = img1_masked[y_start:y_start+size, x_start:x_start+size]
            
            dir_path = f"{out_folder}/img_{image_no}"
            if(not os.path.exists(dir_path)):
                os.mkdir(dir_path)
                
#             print(f"{dir_path}/img_{image_no}_{i+1}_{j+1}.png")
            
            first_digit = str(i+1)
            second_digit = str(j+1)
            if(i+1<10):
                first_digit = f"0{first_digit}"
            if(j+1<10):
                second_digit = f"0{second_digit}"

            cv2.imwrite(f"{dir_path}/img_{image_no}_{first_digit}_{second_digit}.png", img_to_write)
            img_row.append(img_to_write)
            
            x_start = x_end

        a.append(img_row)
        y_start = y_end
        
    return a

# %%
for i in range(1,11):
    segmentation(i, "img_raw", "img_proc")

# %%
for i in range(7):
    segmentation(i, "img_probe", "img_probe")

# %% [markdown]
# # Label the objects

# %% [markdown]
# ## Histogram

# %%
def calc_hist(img):
    img = img[upper_t:lower_t, left_t:right_t]
    
    chans = cv2.split(img)
    colors = ("b", "g", "r")
    
#     plt.figure()
    
    hist_arr = []
#     fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))
    
    # loop over the image channels
    for (chan, color) in zip(chans, colors):
#         plt.title("'Flattened' Color Histogram")
#         plt.xlabel("Bins")
#         plt.ylabel("# of Pixels")
        
        hist = cv2.calcHist([chan], [0], None, [128], [0, 256])
        norm_hist = cv2.normalize(hist, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
        hist_arr.append(norm_hist)
        
        # plot the histogram
#         axes[0].plot(norm_hist, color = color)
#         axes[0].set_xlim([0, 128])
    
#     axes[1].imshow(img[::,::,::-1])
#     plt.show()    
#     plt.close()
    
    return hist_arr

# %%
def plot_hist(hist):
    plt.title("'Flattened' Color Histogram")
    plt.xlabel("Bins")
    plt.ylabel("# of Pixels")
    
    chans = (0, 1, 2)
    colors = ("b", "g", "r")
    for (chan, color) in zip(chans, colors):
        plt.plot(hist[chan], color=color)
    
    plt.show()
    plt.close()

# %% [markdown]
# # Fetch images

# %%
labeled_folder_path = "img_labeled"
labels = [str(i) for i in range(4)]
label_str = ['APPL', 'BG', 'BODY', 'HEAD']
n_label = int(labels[-1]) + 1

(upper_t, lower_t, left_t, right_t) = (6, 34, 6, 34)

# %% [markdown]
# ## Labeled

# %%
def calc_all_hist():
    for label in labels:
        labeled_path = f"{labeled_folder_path}/{label}/"

        hist_label = []
        img_label = []
        for filename in os.listdir(labeled_path):
    #         print(labeled_path + filename)
            img = cv2.imread(labeled_path + filename)
            img_crp = img[upper_t:lower_t, left_t:right_t]
            
            hist_img = calc_hist(img)
            hist_label.append(hist_img)
            img_label.append(img_crp)
        hist_all_label.append(hist_label)
        img_all_label.append(img_label)

# %% [markdown]
# ## Probe

# %%
threshold = 0.5
sample_folder_path = "img_probe"
subfolder_path = [f"{sample_folder_path}/img_{i}/" for i in range(7)]

hist_all_label = []
img_all_label = []
calc_all_hist()

for path in subfolder_path:
    for filename in os.listdir(path):
        img = cv2.imread(path + filename)
        img = img[upper_t:lower_t, left_t:right_t]
        hist_probe = calc_hist(img)
        
        matched_i = -1
        matched_j = -1
        max_coeff = 0
        
        for i in range(n_label):
            for j in range(len(hist_all_label[i])):
                sum_diff = 0
                diffs = []
                for chan in range(3):
                    diff = cv2.compareHist(hist_probe[chan], hist_all_label[i][j][chan], cv2.HISTCMP_CORREL)
                    sum_diff += diff
                    diffs.append(diff)
                
                avg_diff = sum_diff/3
                to_print = False
                if(avg_diff > threshold):
                    to_print = True
                    for k in range(3):
                        if(diffs[k]<threshold):
                            to_print = False
                
                if(to_print):   #  and i!=1 and i!=0
#                     print(f"Average coeff. of ({label_str[i]},{j}) & {filename} = {avg_diff}")
                    
#                     plot_hist(hist_probe)
#                     plot_hist(hist_all_label[i][j])
                    
                    if(avg_diff>max_coeff):
                        max_coeff = avg_diff
                        matched_i = i
                        matched_j = j
                    
        if(max_coeff!=0 and matched_i!=1):    # 
            fig, axes = plt.subplots(ncols=2, nrows=1)
            axes[0].imshow(img[::,::,::-1])
            axes[1].imshow(img_all_label[matched_i][matched_j][::,::,::-1])
            plt.show()
            plt.close()
            print(f"filename = {filename}, label = {label_str[matched_i]}, i = {matched_i}, j = {matched_j}, Max coeff. = {max_coeff}")
            print('----------------------------------------------------------')
    print('========================================================================================')
# Out:
# filename = img_0_02_06.png, label = APPL, i = 0, j = 6, Max coeff. = 0.9980023025737106
# ----------------------------------------------------------
# filename = img_0_05_06.png, label = HEAD, i = 3, j = 5, Max coeff. = 0.7582556093548419
# ----------------------------------------------------------
# filename = img_0_06_06.png, label = BODY, i = 2, j = 0, Max coeff. = 0.983554079227751
# ----------------------------------------------------------
# filename = img_0_07_06.png, label = BODY, i = 2, j = 5, Max coeff. = 0.6074113876915389
# ----------------------------------------------------------
# filename = img_0_08_06.png, label = BODY, i = 2, j = 7, Max coeff. = 0.8560226536992808
# ----------------------------------------------------------
# filename = img_0_10_06.png, label = BODY, i = 2, j = 6, Max coeff. = 0.7798678495477778
# ----------------------------------------------------------
# filename = img_0_10_07.png, label = BODY, i = 2, j = 1, Max coeff. = 0.9613777806520426
# ----------------------------------------------------------
# filename = img_0_10_10.png, label = BODY, i = 2, j = 10, Max coeff. = 0.9294996718353973
# ----------------------------------------------------------
# filename = img_0_10_13.png, label = BODY, i = 2, j = 8, Max coeff. = 0.8958855861626901
# ----------------------------------------------------------
# ========================================================================================
# filename = img_1_02_02.png, label = APPL, i = 0, j = 6, Max coeff. = 0.998319865432614
# ----------------------------------------------------------
# filename = img_1_02_03.png, label = BODY, i = 2, j = 0, Max coeff. = 0.7113387762105284
# ----------------------------------------------------------
# filename = img_1_02_05.png, label = BODY, i = 2, j = 7, Max coeff. = 0.9280867416457549
# ----------------------------------------------------------
# filename = img_1_03_03.png, label = HEAD, i = 3, j = 6, Max coeff. = 0.8337087618407125
# ----------------------------------------------------------
# filename = img_1_04_03.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.9768696292287036
# ----------------------------------------------------------
# filename = img_1_04_05.png, label = BODY, i = 2, j = 6, Max coeff. = 0.5705481684838687
# ----------------------------------------------------------
# filename = img_1_05_05.png, label = BODY, i = 2, j = 1, Max coeff. = 0.9407994722935658
# ----------------------------------------------------------
# filename = img_1_08_05.png, label = BODY, i = 2, j = 10, Max coeff. = 0.8692796145565077
# ----------------------------------------------------------
# filename = img_1_09_07.png, label = BODY, i = 2, j = 2, Max coeff. = 0.8416582135710291
# ----------------------------------------------------------
# ========================================================================================
# filename = img_2_08_06.png, label = BODY, i = 2, j = 10, Max coeff. = 0.756111298888936
# ----------------------------------------------------------
# filename = img_2_08_08.png, label = BODY, i = 2, j = 2, Max coeff. = 0.9126992866939997
# ----------------------------------------------------------
# filename = img_2_08_09.png, label = BODY, i = 2, j = 8, Max coeff. = 0.7620768322798153
# ----------------------------------------------------------
# filename = img_2_09_10.png, label = APPL, i = 0, j = 6, Max coeff. = 0.9980647129050864
# ----------------------------------------------------------
# filename = img_2_10_02.png, label = BODY, i = 2, j = 7, Max coeff. = 0.9823686057722333
# ----------------------------------------------------------
# filename = img_2_11_03.png, label = BODY, i = 2, j = 5, Max coeff. = 0.7371062201684104
# ----------------------------------------------------------
# filename = img_2_11_04.png, label = HEAD, i = 3, j = 6, Max coeff. = 0.8305225529237031
# ----------------------------------------------------------
# filename = img_2_11_05.png, label = HEAD, i = 3, j = 0, Max coeff. = 0.9584360587454587
# ----------------------------------------------------------
# ========================================================================================
# filename = img_3_02_13.png, label = BODY, i = 2, j = 6, Max coeff. = 0.7342540109363602
# ----------------------------------------------------------
# filename = img_3_03_15.png, label = BODY, i = 2, j = 0, Max coeff. = 0.9667687223571776
# ----------------------------------------------------------
# filename = img_3_04_11.png, label = BODY, i = 2, j = 2, Max coeff. = 0.9108038968881983
# ----------------------------------------------------------
# filename = img_3_04_15.png, label = HEAD, i = 3, j = 2, Max coeff. = 0.8923970078143277
# ----------------------------------------------------------
# filename = img_3_06_04.png, label = APPL, i = 0, j = 6, Max coeff. = 0.9984723214406571
# ----------------------------------------------------------
# ========================================================================================
# filename = img_4_03_12.png, label = BODY, i = 2, j = 6, Max coeff. = 0.7204816087415146
# ----------------------------------------------------------
# filename = img_4_03_14.png, label = BODY, i = 2, j = 3, Max coeff. = 0.9356973509838923
# ----------------------------------------------------------
# filename = img_4_03_15.png, label = APPL, i = 0, j = 6, Max coeff. = 0.9981281543611207
# ----------------------------------------------------------
# filename = img_4_04_09.png, label = BODY, i = 2, j = 2, Max coeff. = 0.9213746887355286
# ----------------------------------------------------------
# filename = img_4_04_14.png, label = BODY, i = 2, j = 0, Max coeff. = 0.9304127902962745
# ----------------------------------------------------------
# filename = img_4_05_14.png, label = HEAD, i = 3, j = 1, Max coeff. = 0.9631477383382361
# ----------------------------------------------------------
# ========================================================================================
# filename = img_5_01_15.png, label = APPL, i = 0, j = 6, Max coeff. = 0.9983771568617595
# ----------------------------------------------------------
# filename = img_5_09_10.png, label = BODY, i = 2, j = 10, Max coeff. = 0.9171672152041562
# ----------------------------------------------------------
# filename = img_5_09_12.png, label = BODY, i = 2, j = 1, Max coeff. = 0.887885245771963
# ----------------------------------------------------------
# filename = img_5_09_13.png, label = BODY, i = 2, j = 3, Max coeff. = 0.6519212592253395
# ----------------------------------------------------------
# filename = img_5_10_13.png, label = BODY, i = 2, j = 3, Max coeff. = 0.8772757514583959
# ----------------------------------------------------------
# filename = img_5_11_12.png, label = HEAD, i = 3, j = 5, Max coeff. = 0.8339649352393357
# ----------------------------------------------------------
# filename = img_5_11_13.png, label = BODY, i = 2, j = 5, Max coeff. = 0.8496991338085641
# ----------------------------------------------------------
# ========================================================================================
# filename = img_6_03_09.png, label = BODY, i = 2, j = 1, Max coeff. = 0.8290622795409354
# ----------------------------------------------------------
# filename = img_6_04_08.png, label = BODY, i = 2, j = 9, Max coeff. = 0.909945957994843
# ----------------------------------------------------------
# filename = img_6_05_08.png, label = BODY, i = 2, j = 5, Max coeff. = 0.7252728437472641
# ----------------------------------------------------------
# filename = img_6_06_08.png, label = HEAD, i = 3, j = 2, Max coeff. = 0.9417205870592044
# ----------------------------------------------------------
# filename = img_6_12_13.png, label = APPL, i = 0, j = 6, Max coeff. = 0.9984964849568597
# ----------------------------------------------------------
# ========================================================================================

# %%
img_no = 0
img_filename = f"img_{img_no}_06_06.png"

folder_path = f"img_probe/img_{img_no}"
img_path = f"{folder_path}/{img_filename}"

img_i = cv2.imread(img_path)
img_i = img_i[upper_t:lower_t, left_t:right_t]

hist_i = calc_hist(img_i)

x = 2
y = 0

sum_diff = 0
for chan in range(3):
    diff = cv2.compareHist(hist_i[chan], hist_all_label[x][y][chan], cv2.HISTCMP_CORREL)
    print(diff)
    sum_diff += diff
print('--------------------')
print(sum_diff/3)
    
# plot histograms and show images
plot_hist(hist_i)
plot_hist(hist_all_label[x][y])

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(5,12))
axes[0].imshow(img_i[::,::,::-1])
axes[1].imshow(img_all_label[x][y][::,::,::-1])
plt.show()
plt.close()
# Out:
# 0.9748601120697518
# 0.9933376144157576
# 0.9824645111977433
# --------------------
# 0.983554079227751
