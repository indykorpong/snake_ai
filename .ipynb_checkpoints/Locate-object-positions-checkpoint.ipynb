# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
def open_img(img_path):
    img = cv2.imread(img_path)
    
    (left, upper, right, lower) = (572, 271, 1330, 940)
    img_cropped = img[upper:lower, left:right]
    
    return img_cropped

# %%
def crop_img(img):
    (upper_t, lower_t, left_t, right_t) = (6, 34, 6, 34)
    img = img[upper_t:lower_t, left_t:right_t]
    
    return img

# %% [markdown]
# # Histogram methods

# %%
def calc_hist(img):
    img = img[upper_t:lower_t, left_t:right_t]
    
    chans = cv2.split(img)
    colors = ("b", "g", "r")
    
#     plt.figure()
    
    hist_arr = []
#     fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))
    
    # loop over the image channels
    for (chan, color) in zip(chans, colors):
#         plt.title("'Flattened' Color Histogram")
#         plt.xlabel("Bins")
#         plt.ylabel("# of Pixels")
        
        hist = cv2.calcHist([chan], [0], None, [128], [0, 256])
        norm_hist = cv2.normalize(hist, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
        hist_arr.append(norm_hist)
        
        # plot the histogram
#         axes[0].plot(norm_hist, color = color)
#         axes[0].set_xlim([0, 128])
    
#     axes[1].imshow(img[::,::,::-1])
#     plt.show()    
#     plt.close()
    
    return hist_arr

# %%
def plot_hist(hist):
    plt.title("'Flattened' Color Histogram")
    plt.xlabel("Bins")
    plt.ylabel("# of Pixels")
    
    chans = (0, 1, 2)
    colors = ("b", "g", "r")
    for (chan, color) in zip(chans, colors):
        plt.plot(hist[chan], color=color)
    
    plt.show()
    plt.close()

# %%
def calc_all_hist():
    hist_all_label = []
    img_all_label = []
    
    labeled_folder_path = "img_gallery"
    labels = [str(i) for i in range(4)]
    label_str = ['BG', 'APPL', 'BODY', 'HEAD']
    n_label = int(labels[-1]) + 1
    
    for label in labels:
        labeled_path = f"{labeled_folder_path}/{label}/"

        hist_label = []        
        img_label = []
        for filename in os.listdir(labeled_path):
#             print(labeled_path + filename)
            img = cv2.imread(labeled_path + filename)
            img_crp = crop_img(img)
            
            hist_img = calc_hist(img_crp)
            hist_label.append(hist_img)
            img_label.append(img_crp)
        hist_all_label.append(hist_label)
        img_all_label.append(img_label)
        
    return hist_all_label, img_all_label

# %% [markdown]
# # Preprocessing methods

# %%
def preprocessing(img):
    bg = open_img("img_raw/bg.png")
    
    # background subtraction
    img_sub = cv2.subtract(img, bg)
    
    # masking the image with the background
    img_gray = cv2.cvtColor(img_sub, cv2.COLOR_BGR2GRAY)
    ret,thresh1 = cv2.threshold(img_gray,5,255,cv2.THRESH_BINARY)

    kernel = np.ones((3,3),np.uint8)
    erosion = cv2.erode(thresh1,kernel,iterations = 2)
    dilation = cv2.dilate(erosion,kernel,iterations = 2)
    
    img_masked = cv2.bitwise_and(img, img, mask=dilation)
    
    return img_masked

# %%
def separate_img_to_tiles(img, image_no, out_folder):
    nrows = 15
    ncols = 17
    img_tiles = []

    size = 40
    w_start = 35
    h_start = 31

    y_start = h_start
    for i in range(nrows):
        if(i%2==0):
            y_end = y_start + size
        elif(i%2==1):
            y_end = y_start + (size+1)

        img_row = []
        x_start = w_start
        for j in range(ncols):
            if(j%2==0):
                x_end = x_start + (size+1)
            elif(j%2==1):
                x_end = x_start + size
            
            img_i = img[y_start:y_start+size, x_start:x_start+size]
            img_row.append(img_i)
            
            dir_path = f"{out_folder}/img_{image_no}"
            if(not os.path.exists(dir_path)):
                os.mkdir(dir_path)
            
            first_digit = str(i+1)
            second_digit = str(j+1)
            if(i+1<10):
                first_digit = f"0{first_digit}"
            if(j+1<10):
                second_digit = f"0{second_digit}"
                
            img_no = str(image_no)
            if(image_no<10):
                img_no = f"0{image_no}"

            cv2.imwrite(f"{dir_path}/img_{img_no}_{first_digit}_{second_digit}.png", img_i)
            
            # set the rightmost x-coordinate to be the new x_start
            x_start = x_end
            
        # set the bottommost y-coordinate to be the new y_start
        y_start = y_end
        
        img_tiles.append(img_row)
    
    return img_tiles

# %%
def segmentation(image_no, in_folder, out_folder):
    img_path = f"{in_folder}/{image_no}.png"
    img = open_img(img_path)    
    img_pp = preprocessing(img)
    img_tiles = separate_img_to_tiles(img_pp, image_no, out_folder)
        
    return img_tiles

# %% [markdown]
# # Prediction method

# %%
def predict_img_label(img, hist_all_label, threshold):
    img = crop_img(img)
    hist_img = calc_hist(img)
    
    threshold_bg = 0.9
    threshold_0 = threshold
    
    matched_i = -1
    matched_j = -1
    max_coeff = -1
    
    for i in range(n_label):
        for j in range(len(hist_all_label[i])):
            sum_diff = 0
            diffs = []
            for chan in range(3):
                diff = cv2.compareHist(hist_img[chan], hist_all_label[i][j][chan], cv2.HISTCMP_CORREL)
                sum_diff += diff
                diffs.append(diff)

            avg_diff = sum_diff/3
            to_print = False
            
            threshold_0 = threshold_bg if(i==0) else threshold
                
            if(avg_diff > threshold_0):
                to_print = True
                for k in range(3):
                    if(diffs[k]<threshold_0):
                        to_print = False

            if(to_print):
                if(avg_diff>max_coeff):
                    max_coeff = avg_diff
                    matched_i = i
                    matched_j = j
    
    if(max_coeff!=-1):
        return matched_i, matched_j, max_coeff
    
    return 0, -1, 0

# %% [markdown]
# # Executions

# %%
image_no = 11
bg = open_img("img_raw/bg.png")
img1 = open_img(f"img_raw/{image_no}.png")

bg_gray = cv2.cvtColor(bg, cv2.COLOR_BGR2GRAY)
img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# %%
for i in range(1,17):
    segmentation(i, "img_raw", "img_proc")

# %%
for i in range(18):
    segmentation(i, "img_probe", "img_probe")

# %% [markdown]
# ## Demo

# %%
labeled_folder_path = "img_gallery"
labels = [str(i) for i in range(4)]
label_str = ['BG', 'APPL', 'BODY', 'HEAD']
n_label = int(labels[-1]) + 1

(upper_t, lower_t, left_t, right_t) = (6, 34, 6, 34)

# %%
sample_folder_path = "img_probe"
subfolder_path = [f"{sample_folder_path}/img_{i}/" for i in range(17)]

threshold = -1
hist_all_label = []
img_all_label = []
hist_all_label, img_all_label = calc_all_hist()

for path in subfolder_path:
    for filename in os.listdir(path):
        img = cv2.imread(path + filename)
        img = crop_img(img)
        
        img_label, img_no, max_coeff = predict_img_label(img, hist_all_label, threshold)
        
        if(img_label!=-1 and img_label!=0):
            fig, axes = plt.subplots(ncols=2, nrows=1)
            axes[0].imshow(img[::,::,::-1])
            axes[1].imshow(img_all_label[img_label][img_no][::,::,::-1])
            plt.show()
            plt.close()
            print(f"filename = {filename}, label = {label_str[img_label]}, i = {img_label}, j = {img_no}, Max coeff. = {max_coeff}")
            print('----------------------------------------------------------')
    print('========================================================================================')
# Out:
# filename = img_0_02_06.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# filename = img_0_05_06.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.7187937863298067
# ----------------------------------------------------------
# filename = img_0_06_06.png, label = BODY, i = 2, j = 3, Max coeff. = 0.5360373733271128
# ----------------------------------------------------------
# filename = img_0_07_06.png, label = BODY, i = 2, j = 1, Max coeff. = 0.6170213072989343
# ----------------------------------------------------------
# filename = img_0_08_06.png, label = BODY, i = 2, j = 5, Max coeff. = 0.9723521743720189
# ----------------------------------------------------------
# filename = img_0_09_06.png, label = BODY, i = 2, j = 14, Max coeff. = 0.4019304456253643
# ----------------------------------------------------------
# filename = img_0_10_06.png, label = BODY, i = 2, j = 4, Max coeff. = 0.9397093432760876
# ----------------------------------------------------------
# filename = img_0_10_07.png, label = BODY, i = 2, j = 4, Max coeff. = 0.0923964227020213
# ----------------------------------------------------------
# filename = img_0_10_08.png, label = BODY, i = 2, j = 15, Max coeff. = 0.9724397725361439
# ----------------------------------------------------------
# filename = img_0_10_09.png, label = BODY, i = 2, j = 10, Max coeff. = 0.2213996039789691
# ----------------------------------------------------------
# filename = img_0_10_10.png, label = BODY, i = 2, j = 7, Max coeff. = 0.8430689087036752
# ----------------------------------------------------------
# filename = img_0_10_11.png, label = BODY, i = 2, j = 16, Max coeff. = 0.6897659615424149
# ----------------------------------------------------------
# filename = img_0_10_12.png, label = BODY, i = 2, j = 18, Max coeff. = 0.7275349645795058
# ----------------------------------------------------------
# filename = img_0_10_13.png, label = BODY, i = 2, j = 6, Max coeff. = 0.9599490302591724
# ----------------------------------------------------------
# filename = img_0_10_14.png, label = BODY, i = 2, j = 17, Max coeff. = 0.27950001115162004
# ----------------------------------------------------------
# filename = img_0_10_15.png, label = BODY, i = 2, j = 11, Max coeff. = 0.9709226197729374
# ----------------------------------------------------------
# ========================================================================================
# filename = img_1_02_02.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# filename = img_1_02_03.png, label = BODY, i = 2, j = 3, Max coeff. = 0.8112987809471247
# ----------------------------------------------------------
# filename = img_1_02_04.png, label = BODY, i = 2, j = 1, Max coeff. = 0.6785297160025587
# ----------------------------------------------------------
# filename = img_1_02_05.png, label = BODY, i = 2, j = 5, Max coeff. = 0.939040444577328
# ----------------------------------------------------------
# filename = img_1_03_03.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.5266335709498353
# ----------------------------------------------------------
# filename = img_1_03_05.png, label = BODY, i = 2, j = 14, Max coeff. = 0.3748649907794161
# ----------------------------------------------------------
# filename = img_1_04_03.png, label = HEAD, i = 3, j = 2, Max coeff. = 0.9782250345389474
# ----------------------------------------------------------
# filename = img_1_04_05.png, label = BODY, i = 2, j = 4, Max coeff. = 0.8028118795898301
# ----------------------------------------------------------
# filename = img_1_05_05.png, label = BODY, i = 2, j = 4, Max coeff. = 0.08139291514900777
# ----------------------------------------------------------
# filename = img_1_06_05.png, label = BODY, i = 2, j = 15, Max coeff. = 0.9230098843334136
# ----------------------------------------------------------
# filename = img_1_07_05.png, label = BODY, i = 2, j = 10, Max coeff. = 0.21225408125748343
# ----------------------------------------------------------
# filename = img_1_08_05.png, label = BODY, i = 2, j = 7, Max coeff. = 0.9118976995955063
# ----------------------------------------------------------
# filename = img_1_09_05.png, label = BODY, i = 2, j = 16, Max coeff. = 0.8701339220080948
# ----------------------------------------------------------
# filename = img_1_09_06.png, label = BODY, i = 2, j = 18, Max coeff. = 0.9169837328701546
# ----------------------------------------------------------
# filename = img_1_09_07.png, label = BODY, i = 2, j = 8, Max coeff. = 0.9125960344898467
# ----------------------------------------------------------
# filename = img_1_09_08.png, label = BODY, i = 2, j = 17, Max coeff. = 0.35659957084816724
# ----------------------------------------------------------
# filename = img_1_09_09.png, label = BODY, i = 2, j = 11, Max coeff. = 0.5461179200342711
# ----------------------------------------------------------
# filename = img_1_09_10.png, label = BODY, i = 2, j = 11, Max coeff. = 0.6014700980359741
# ----------------------------------------------------------
# ========================================================================================
# filename = img_2_07_11.png, label = BODY, i = 2, j = 12, Max coeff. = 0.932266294709216
# ----------------------------------------------------------
# filename = img_2_08_02.png, label = BODY, i = 2, j = 4, Max coeff. = 0.566215085293129
# ----------------------------------------------------------
# filename = img_2_08_03.png, label = BODY, i = 2, j = 15, Max coeff. = 0.09441319214464443
# ----------------------------------------------------------
# filename = img_2_08_04.png, label = BODY, i = 2, j = 10, Max coeff. = 0.7145839789693292
# ----------------------------------------------------------
# filename = img_2_08_05.png, label = BODY, i = 2, j = 7, Max coeff. = 0.30090088205257515
# ----------------------------------------------------------
# filename = img_2_08_06.png, label = BODY, i = 2, j = 9, Max coeff. = 0.8521523901837561
# ----------------------------------------------------------
# filename = img_2_08_07.png, label = BODY, i = 2, j = 16, Max coeff. = 0.5953891355540364
# ----------------------------------------------------------
# filename = img_2_08_08.png, label = BODY, i = 2, j = 0, Max coeff. = 0.8523637673731713
# ----------------------------------------------------------
# filename = img_2_08_09.png, label = BODY, i = 2, j = 6, Max coeff. = 0.651834274285417
# ----------------------------------------------------------
# filename = img_2_08_10.png, label = BODY, i = 2, j = 17, Max coeff. = 0.3921290542567035
# ----------------------------------------------------------
# filename = img_2_09_02.png, label = BODY, i = 2, j = 14, Max coeff. = 0.4129927222490495
# ----------------------------------------------------------
# filename = img_2_09_10.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# filename = img_2_10_02.png, label = BODY, i = 2, j = 5, Max coeff. = 0.991837036963051
# ----------------------------------------------------------
# filename = img_2_11_02.png, label = BODY, i = 2, j = 1, Max coeff. = 0.5027759936162582
# ----------------------------------------------------------
# filename = img_2_11_03.png, label = BODY, i = 2, j = 3, Max coeff. = 0.7253953642038108
# ----------------------------------------------------------
# filename = img_2_11_04.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.5761646849893217
# ----------------------------------------------------------
# filename = img_2_11_05.png, label = HEAD, i = 3, j = 0, Max coeff. = 0.7533193373733528
# ----------------------------------------------------------
# ========================================================================================
# filename = img_3_02_11.png, label = BODY, i = 2, j = 7, Max coeff. = 0.43788644317517106
# ----------------------------------------------------------
# filename = img_3_02_12.png, label = BODY, i = 2, j = 15, Max coeff. = 0.6841563043729937
# ----------------------------------------------------------
# filename = img_3_02_13.png, label = BODY, i = 2, j = 4, Max coeff. = 0.805229826313214
# ----------------------------------------------------------
# filename = img_3_02_14.png, label = BODY, i = 2, j = 14, Max coeff. = 0.5652784268770722
# ----------------------------------------------------------
# filename = img_3_02_15.png, label = BODY, i = 2, j = 1, Max coeff. = 0.5503577217731096
# ----------------------------------------------------------
# filename = img_3_03_11.png, label = BODY, i = 2, j = 16, Max coeff. = 0.5774170159470811
# ----------------------------------------------------------
# filename = img_3_03_15.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.39197989994950455
# ----------------------------------------------------------
# filename = img_3_04_11.png, label = BODY, i = 2, j = 8, Max coeff. = 0.8222038013874166
# ----------------------------------------------------------
# filename = img_3_04_15.png, label = HEAD, i = 3, j = 1, Max coeff. = 0.8819318566832685
# ----------------------------------------------------------
# filename = img_3_05_11.png, label = BODY, i = 2, j = 6, Max coeff. = 0.07345310013109678
# ----------------------------------------------------------
# filename = img_3_06_04.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# filename = img_3_06_11.png, label = BODY, i = 2, j = 11, Max coeff. = 0.7673140024122006
# ----------------------------------------------------------
# ========================================================================================
# filename = img_4_03_09.png, label = BODY, i = 2, j = 16, Max coeff. = 0.5831025315623372
# ----------------------------------------------------------
# filename = img_4_03_10.png, label = BODY, i = 2, j = 7, Max coeff. = 0.32843622967763825
# ----------------------------------------------------------
# filename = img_4_03_11.png, label = BODY, i = 2, j = 15, Max coeff. = 0.8302512606801423
# ----------------------------------------------------------
# filename = img_4_03_12.png, label = BODY, i = 2, j = 4, Max coeff. = 0.802339366440136
# ----------------------------------------------------------
# filename = img_4_03_13.png, label = BODY, i = 2, j = 14, Max coeff. = 0.5526577185643852
# ----------------------------------------------------------
# filename = img_4_03_14.png, label = BODY, i = 2, j = 1, Max coeff. = 0.8606075344087104
# ----------------------------------------------------------
# filename = img_4_03_15.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# filename = img_4_04_09.png, label = BODY, i = 2, j = 8, Max coeff. = 0.9203179343604426
# ----------------------------------------------------------
# filename = img_4_04_14.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.3674732168956485
# ----------------------------------------------------------
# filename = img_4_05_09.png, label = BODY, i = 2, j = 17, Max coeff. = 0.7211842926010169
# ----------------------------------------------------------
# filename = img_4_05_14.png, label = HEAD, i = 3, j = 0, Max coeff. = 0.9442558064373613
# ----------------------------------------------------------
# ========================================================================================
# filename = img_5_01_15.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# filename = img_5_09_10.png, label = BODY, i = 2, j = 7, Max coeff. = 0.9089958889291081
# ----------------------------------------------------------
# filename = img_5_09_11.png, label = BODY, i = 2, j = 10, Max coeff. = 0.7459188909083689
# ----------------------------------------------------------
# filename = img_5_09_12.png, label = BODY, i = 2, j = 4, Max coeff. = 0.14300094510864622
# ----------------------------------------------------------
# filename = img_5_09_13.png, label = BODY, i = 2, j = 1, Max coeff. = 0.8165674568871149
# ----------------------------------------------------------
# filename = img_5_10_13.png, label = BODY, i = 2, j = 2, Max coeff. = 0.7782062401792027
# ----------------------------------------------------------
# filename = img_5_11_11.png, label = HEAD, i = 3, j = 2, Max coeff. = 0.8854701667235824
# ----------------------------------------------------------
# filename = img_5_11_12.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.7090552018748865
# ----------------------------------------------------------
# filename = img_5_11_13.png, label = BODY, i = 2, j = 17, Max coeff. = 0.7371788371376441
# ----------------------------------------------------------
# ========================================================================================
# filename = img_6_03_08.png, label = BODY, i = 2, j = 4, Max coeff. = 0.2944245351235367
# ----------------------------------------------------------
# filename = img_6_03_09.png, label = BODY, i = 2, j = 15, Max coeff. = 0.15803014653179565
# ----------------------------------------------------------
# filename = img_6_03_10.png, label = BODY, i = 2, j = 10, Max coeff. = 0.8222744771011873
# ----------------------------------------------------------
# filename = img_6_04_08.png, label = BODY, i = 2, j = 1, Max coeff. = 0.7716015297650993
# ----------------------------------------------------------
# filename = img_6_05_08.png, label = BODY, i = 2, j = 3, Max coeff. = 0.683383871467945
# ----------------------------------------------------------
# filename = img_6_06_08.png, label = HEAD, i = 3, j = 1, Max coeff. = 0.9457499359696646
# ----------------------------------------------------------
# filename = img_6_12_13.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# ========================================================================================
# filename = img_7_08_04.png, label = BODY, i = 2, j = 13, Max coeff. = 0.8479081054023165
# ----------------------------------------------------------
# filename = img_7_09_04.png, label = BODY, i = 2, j = 11, Max coeff. = 0.5760827428663852
# ----------------------------------------------------------
# filename = img_7_10_04.png, label = BODY, i = 2, j = 11, Max coeff. = 0.6251731506964956
# ----------------------------------------------------------
# filename = img_7_11_04.png, label = BODY, i = 2, j = 17, Max coeff. = 0.3635000357415794
# ----------------------------------------------------------
# filename = img_7_11_17.png, label = APPL, i = 1, j = 2, Max coeff. = 0.9845994393602547
# ----------------------------------------------------------
# filename = img_7_12_04.png, label = BODY, i = 2, j = 8, Max coeff. = 0.8073841034015108
# ----------------------------------------------------------
# filename = img_7_13_04.png, label = BODY, i = 2, j = 0, Max coeff. = 0.8299552077716498
# ----------------------------------------------------------
# filename = img_7_14_04.png, label = BODY, i = 2, j = 16, Max coeff. = 0.5838078556022283
# ----------------------------------------------------------
# filename = img_7_15_04.png, label = BODY, i = 2, j = 17, Max coeff. = 0.7372733732034984
# ----------------------------------------------------------
# filename = img_7_15_05.png, label = BODY, i = 2, j = 7, Max coeff. = 0.7525820543227383
# ----------------------------------------------------------
# filename = img_7_15_06.png, label = BODY, i = 2, j = 10, Max coeff. = 0.19148417206963578
# ----------------------------------------------------------
# filename = img_7_15_07.png, label = BODY, i = 2, j = 15, Max coeff. = 0.9577717264060833
# ----------------------------------------------------------
# filename = img_7_15_08.png, label = BODY, i = 2, j = 4, Max coeff. = 0.10235357699317793
# ----------------------------------------------------------
# filename = img_7_15_09.png, label = BODY, i = 2, j = 4, Max coeff. = 0.5517908153848793
# ----------------------------------------------------------
# filename = img_7_15_10.png, label = BODY, i = 2, j = 4, Max coeff. = 0.3649813855911719
# ----------------------------------------------------------
# filename = img_7_15_11.png, label = BODY, i = 2, j = 14, Max coeff. = 0.4218133064171095
# ----------------------------------------------------------
# filename = img_7_15_12.png, label = BODY, i = 2, j = 5, Max coeff. = 0.9864037971876757
# ----------------------------------------------------------
# filename = img_7_15_13.png, label = BODY, i = 2, j = 1, Max coeff. = 0.8282743414559826
# ----------------------------------------------------------
# filename = img_7_15_14.png, label = BODY, i = 2, j = 3, Max coeff. = 0.7669096197991218
# ----------------------------------------------------------
# filename = img_7_15_15.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.44098127134138426
# ----------------------------------------------------------
# filename = img_7_15_16.png, label = HEAD, i = 3, j = 4, Max coeff. = 0.7767229319545278
# ----------------------------------------------------------
# ========================================================================================
# filename = img_8_03_07.png, label = HEAD, i = 3, j = 1, Max coeff. = 0.872358831964808
# ----------------------------------------------------------
# filename = img_8_03_08.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.4554594026948721
# ----------------------------------------------------------
# filename = img_8_03_09.png, label = BODY, i = 2, j = 3, Max coeff. = 0.732753911930495
# ----------------------------------------------------------
# filename = img_8_03_10.png, label = BODY, i = 2, j = 1, Max coeff. = 0.8255182843534238
# ----------------------------------------------------------
# filename = img_8_03_11.png, label = BODY, i = 2, j = 5, Max coeff. = 0.6251156597948343
# ----------------------------------------------------------
# filename = img_8_03_12.png, label = BODY, i = 2, j = 4, Max coeff. = 0.4907716120599825
# ----------------------------------------------------------
# filename = img_8_04_12.png, label = BODY, i = 2, j = 4, Max coeff. = 0.7512351176499533
# ----------------------------------------------------------
# filename = img_8_05_12.png, label = BODY, i = 2, j = 15, Max coeff. = 0.12427635126891358
# ----------------------------------------------------------
# filename = img_8_06_12.png, label = BODY, i = 2, j = 15, Max coeff. = 0.986359476707431
# ----------------------------------------------------------
# filename = img_8_07_12.png, label = BODY, i = 2, j = 7, Max coeff. = 0.2574337891322946
# ----------------------------------------------------------
# filename = img_8_08_12.png, label = BODY, i = 2, j = 7, Max coeff. = 0.9042586401945484
# ----------------------------------------------------------
# filename = img_8_09_12.png, label = BODY, i = 2, j = 16, Max coeff. = 0.576704040985689
# ----------------------------------------------------------
# filename = img_8_10_12.png, label = BODY, i = 2, j = 18, Max coeff. = 0.5439663773406821
# ----------------------------------------------------------
# filename = img_8_11_08.png, label = BODY, i = 2, j = 13, Max coeff. = 0.71680614063916
# ----------------------------------------------------------
# filename = img_8_11_09.png, label = BODY, i = 2, j = 11, Max coeff. = 0.6417950824171257
# ----------------------------------------------------------
# filename = img_8_11_10.png, label = BODY, i = 2, j = 11, Max coeff. = 0.6578493594716348
# ----------------------------------------------------------
# filename = img_8_11_11.png, label = BODY, i = 2, j = 17, Max coeff. = 0.4354049362177
# ----------------------------------------------------------
# filename = img_8_12_07.png, label = APPL, i = 1, j = 7, Max coeff. = 0.9733016530363355
# ----------------------------------------------------------
# ========================================================================================
# filename = img_9_03_08.png, label = APPL, i = 1, j = 2, Max coeff. = 0.9461072638648872
# ----------------------------------------------------------
# filename = img_9_09_05.png, label = BODY, i = 2, j = 18, Max coeff. = 0.7491433638227541
# ----------------------------------------------------------
# filename = img_9_09_06.png, label = BODY, i = 2, j = 6, Max coeff. = 0.7559888477868143
# ----------------------------------------------------------
# filename = img_9_09_07.png, label = BODY, i = 2, j = 11, Max coeff. = 0.7776287418239605
# ----------------------------------------------------------
# filename = img_9_10_05.png, label = BODY, i = 2, j = 7, Max coeff. = 0.930194989711077
# ----------------------------------------------------------
# filename = img_9_11_05.png, label = BODY, i = 2, j = 7, Max coeff. = 0.18392142250319488
# ----------------------------------------------------------
# filename = img_9_12_05.png, label = BODY, i = 2, j = 4, Max coeff. = 0.0565001898804059
# ----------------------------------------------------------
# filename = img_9_13_05.png, label = BODY, i = 2, j = 4, Max coeff. = 0.33823182251141715
# ----------------------------------------------------------
# filename = img_9_14_05.png, label = BODY, i = 2, j = 2, Max coeff. = 0.919274476110245
# ----------------------------------------------------------
# filename = img_9_14_06.png, label = BODY, i = 2, j = 3, Max coeff. = 0.9182171617979487
# ----------------------------------------------------------
# filename = img_9_14_07.png, label = HEAD, i = 3, j = 4, Max coeff. = 0.7522976076449451
# ----------------------------------------------------------
# ========================================================================================
# filename = img_10_03_01.png, label = BODY, i = 2, j = 8, Max coeff. = 0.8663138285658408
# ----------------------------------------------------------
# filename = img_10_03_02.png, label = BODY, i = 2, j = 18, Max coeff. = 0.9198736752712842
# ----------------------------------------------------------
# filename = img_10_03_03.png, label = BODY, i = 2, j = 9, Max coeff. = 0.7928631066720971
# ----------------------------------------------------------
# filename = img_10_03_04.png, label = BODY, i = 2, j = 7, Max coeff. = 0.8339192604155333
# ----------------------------------------------------------
# filename = img_10_03_05.png, label = BODY, i = 2, j = 10, Max coeff. = 0.7379704608135954
# ----------------------------------------------------------
# filename = img_10_03_06.png, label = BODY, i = 2, j = 15, Max coeff. = 0.02387306628023343
# ----------------------------------------------------------
# filename = img_10_03_07.png, label = BODY, i = 2, j = 4, Max coeff. = 0.6628793935169651
# ----------------------------------------------------------
# filename = img_10_03_08.png, label = BODY, i = 2, j = 4, Max coeff. = 0.2165576193533404
# ----------------------------------------------------------
# filename = img_10_03_09.png, label = BODY, i = 2, j = 5, Max coeff. = 0.7701660311825679
# ----------------------------------------------------------
# filename = img_10_03_10.png, label = BODY, i = 2, j = 1, Max coeff. = 0.8465429759547861
# ----------------------------------------------------------
# filename = img_10_03_11.png, label = BODY, i = 2, j = 3, Max coeff. = 0.7850998041431988
# ----------------------------------------------------------
# filename = img_10_03_12.png, label = HEAD, i = 3, j = 4, Max coeff. = 0.6915871506488426
# ----------------------------------------------------------
# filename = img_10_04_01.png, label = BODY, i = 2, j = 11, Max coeff. = 0.32258708300848676
# ----------------------------------------------------------
# filename = img_10_05_01.png, label = BODY, i = 2, j = 11, Max coeff. = 0.6588691585511163
# ----------------------------------------------------------
# filename = img_10_06_01.png, label = BODY, i = 2, j = 13, Max coeff. = 0.5655179290786003
# ----------------------------------------------------------
# filename = img_10_06_15.png, label = APPL, i = 1, j = 2, Max coeff. = 0.9617233715679708
# ----------------------------------------------------------
# ========================================================================================
# filename = img_11_02_16.png, label = APPL, i = 1, j = 2, Max coeff. = 0.9832943570913543
# ----------------------------------------------------------
# filename = img_11_03_16.png, label = HEAD, i = 3, j = 0, Max coeff. = 0.763563316640062
# ----------------------------------------------------------
# filename = img_11_04_16.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.5119035593163592
# ----------------------------------------------------------
# filename = img_11_05_16.png, label = BODY, i = 2, j = 3, Max coeff. = 0.8938667306328235
# ----------------------------------------------------------
# filename = img_11_06_16.png, label = BODY, i = 2, j = 3, Max coeff. = 0.3710498712685352
# ----------------------------------------------------------
# filename = img_11_07_16.png, label = BODY, i = 2, j = 2, Max coeff. = 0.7728534744713516
# ----------------------------------------------------------
# filename = img_11_08_16.png, label = BODY, i = 2, j = 5, Max coeff. = 0.6654701118850636
# ----------------------------------------------------------
# filename = img_11_09_16.png, label = BODY, i = 2, j = 14, Max coeff. = 0.3843420507283184
# ----------------------------------------------------------
# filename = img_11_10_16.png, label = BODY, i = 2, j = 4, Max coeff. = 0.7225166010081794
# ----------------------------------------------------------
# filename = img_11_11_16.png, label = BODY, i = 2, j = 4, Max coeff. = 0.4650674826361801
# ----------------------------------------------------------
# filename = img_11_12_16.png, label = BODY, i = 2, j = 15, Max coeff. = 0.29666096051889884
# ----------------------------------------------------------
# filename = img_11_13_16.png, label = BODY, i = 2, j = 15, Max coeff. = 0.8460403189544969
# ----------------------------------------------------------
# filename = img_11_14_05.png, label = BODY, i = 2, j = 17, Max coeff. = 0.8311239770261986
# ----------------------------------------------------------
# filename = img_11_14_06.png, label = BODY, i = 2, j = 13, Max coeff. = 0.64853393614207
# ----------------------------------------------------------
# filename = img_11_14_07.png, label = BODY, i = 2, j = 11, Max coeff. = 0.9019671816522035
# ----------------------------------------------------------
# filename = img_11_14_08.png, label = BODY, i = 2, j = 11, Max coeff. = 0.5523524410906661
# ----------------------------------------------------------
# filename = img_11_14_09.png, label = BODY, i = 2, j = 17, Max coeff. = 0.42684863798988965
# ----------------------------------------------------------
# filename = img_11_14_10.png, label = BODY, i = 2, j = 8, Max coeff. = 0.8261818086775001
# ----------------------------------------------------------
# filename = img_11_14_11.png, label = BODY, i = 2, j = 0, Max coeff. = 0.940955471392592
# ----------------------------------------------------------
# filename = img_11_14_12.png, label = BODY, i = 2, j = 18, Max coeff. = 0.763802558286787
# ----------------------------------------------------------
# filename = img_11_14_13.png, label = BODY, i = 2, j = 9, Max coeff. = 0.682580720933696
# ----------------------------------------------------------
# filename = img_11_14_14.png, label = BODY, i = 2, j = 7, Max coeff. = 0.9409412046241825
# ----------------------------------------------------------
# filename = img_11_14_15.png, label = BODY, i = 2, j = 7, Max coeff. = 0.4488416074900825
# ----------------------------------------------------------
# ========================================================================================
# filename = img_12_03_08.png, label = BODY, i = 2, j = 17, Max coeff. = 0.5949213700193602
# ----------------------------------------------------------
# filename = img_12_09_05.png, label = BODY, i = 2, j = 15, Max coeff. = 0.7433189688750623
# ----------------------------------------------------------
# filename = img_12_09_06.png, label = BODY, i = 2, j = 7, Max coeff. = 0.8653380917259015
# ----------------------------------------------------------
# filename = img_12_09_07.png, label = BODY, i = 2, j = 16, Max coeff. = 0.5342435695004589
# ----------------------------------------------------------
# filename = img_12_09_08.png, label = BODY, i = 2, j = 8, Max coeff. = 0.9114540434248632
# ----------------------------------------------------------
# filename = img_12_09_09.png, label = BODY, i = 2, j = 6, Max coeff. = 0.31824045666086165
# ----------------------------------------------------------
# filename = img_12_10_05.png, label = BODY, i = 2, j = 4, Max coeff. = 0.6027082180463131
# ----------------------------------------------------------
# filename = img_12_11_05.png, label = BODY, i = 2, j = 14, Max coeff. = 0.5471146674206572
# ----------------------------------------------------------
# filename = img_12_12_05.png, label = BODY, i = 2, j = 1, Max coeff. = 0.9213804511954247
# ----------------------------------------------------------
# filename = img_12_13_05.png, label = BODY, i = 2, j = 3, Max coeff. = 0.6530506880651311
# ----------------------------------------------------------
# filename = img_12_14_05.png, label = HEAD, i = 3, j = 2, Max coeff. = 0.4325925433087148
# ----------------------------------------------------------
# ========================================================================================
# filename = img_13_03_03.png, label = APPL, i = 1, j = 2, Max coeff. = 0.9902106112764489
# ----------------------------------------------------------
# filename = img_13_13_01.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.7270481876825511
# ----------------------------------------------------------
# filename = img_13_13_08.png, label = BODY, i = 2, j = 18, Max coeff. = 0.7248613615865557
# ----------------------------------------------------------
# filename = img_13_13_09.png, label = BODY, i = 2, j = 8, Max coeff. = 0.9823835080577314
# ----------------------------------------------------------
# filename = img_13_13_10.png, label = BODY, i = 2, j = 17, Max coeff. = 0.29239110060100165
# ----------------------------------------------------------
# filename = img_13_13_11.png, label = BODY, i = 2, j = 11, Max coeff. = 0.7671212209103325
# ----------------------------------------------------------
# filename = img_13_13_12.png, label = BODY, i = 2, j = 13, Max coeff. = 0.8351895959965475
# ----------------------------------------------------------
# filename = img_13_14_01.png, label = BODY, i = 2, j = 3, Max coeff. = 0.9247509216105066
# ----------------------------------------------------------
# filename = img_13_14_02.png, label = BODY, i = 2, j = 1, Max coeff. = 0.8014378260232417
# ----------------------------------------------------------
# filename = img_13_14_03.png, label = BODY, i = 2, j = 14, Max coeff. = 0.5746394978055939
# ----------------------------------------------------------
# filename = img_13_14_04.png, label = BODY, i = 2, j = 4, Max coeff. = 0.4325183867875624
# ----------------------------------------------------------
# filename = img_13_14_05.png, label = BODY, i = 2, j = 4, Max coeff. = 0.3103917134866282
# ----------------------------------------------------------
# filename = img_13_14_06.png, label = BODY, i = 2, j = 15, Max coeff. = 0.907434228302007
# ----------------------------------------------------------
# filename = img_13_14_07.png, label = BODY, i = 2, j = 10, Max coeff. = 0.17830465907859985
# ----------------------------------------------------------
# ========================================================================================
# filename = img_14_02_05.png, label = APPL, i = 1, j = 7, Max coeff. = 0.4158476977913617
# ----------------------------------------------------------
# filename = img_14_04_13.png, label = BODY, i = 2, j = 11, Max coeff. = 0.5171285808500329
# ----------------------------------------------------------
# filename = img_14_04_14.png, label = HEAD, i = 3, j = 4, Max coeff. = 0.5812412465411746
# ----------------------------------------------------------
# filename = img_14_05_14.png, label = BODY, i = 2, j = 3, Max coeff. = 0.7190891648697878
# ----------------------------------------------------------
# filename = img_14_06_10.png, label = BODY, i = 2, j = 4, Max coeff. = 0.7695507541875056
# ----------------------------------------------------------
# filename = img_14_06_11.png, label = BODY, i = 2, j = 4, Max coeff. = 0.3325932032888777
# ----------------------------------------------------------
# filename = img_14_06_12.png, label = BODY, i = 2, j = 5, Max coeff. = 0.6325859479376426
# ----------------------------------------------------------
# filename = img_14_06_13.png, label = BODY, i = 2, j = 1, Max coeff. = 0.8409159795773272
# ----------------------------------------------------------
# filename = img_14_06_14.png, label = BODY, i = 2, j = 17, Max coeff. = 0.8355365750309195
# ----------------------------------------------------------
# filename = img_14_07_10.png, label = BODY, i = 2, j = 15, Max coeff. = 0.175308551880333
# ----------------------------------------------------------
# filename = img_14_08_10.png, label = BODY, i = 2, j = 15, Max coeff. = 0.6083606969203635
# ----------------------------------------------------------
# filename = img_14_09_10.png, label = BODY, i = 2, j = 7, Max coeff. = 0.6840585616995342
# ----------------------------------------------------------
# filename = img_14_10_10.png, label = BODY, i = 2, j = 9, Max coeff. = 0.9030587989016946
# ----------------------------------------------------------
# filename = img_14_11_10.png, label = BODY, i = 2, j = 16, Max coeff. = 0.9306311675897802
# ----------------------------------------------------------
# filename = img_14_11_11.png, label = BODY, i = 2, j = 0, Max coeff. = 0.5947735085655305
# ----------------------------------------------------------
# filename = img_14_11_12.png, label = BODY, i = 2, j = 6, Max coeff. = 0.7911229817972738
# ----------------------------------------------------------
# filename = img_14_11_13.png, label = BODY, i = 2, j = 17, Max coeff. = 0.3917189831237209
# ----------------------------------------------------------
# filename = img_14_11_14.png, label = BODY, i = 2, j = 11, Max coeff. = 0.7813199358778341
# ----------------------------------------------------------
# filename = img_14_11_15.png, label = BODY, i = 2, j = 12, Max coeff. = 0.8928208801705675
# ----------------------------------------------------------
# filename = img_14_11_16.png, label = BODY, i = 2, j = 13, Max coeff. = 0.6220623087147711
# ----------------------------------------------------------
# ========================================================================================
# filename = img_15_09_17.png, label = BODY, i = 2, j = 0, Max coeff. = 0.9549091905299664
# ----------------------------------------------------------
# filename = img_15_10_17.png, label = BODY, i = 2, j = 16, Max coeff. = 0.555785976654882
# ----------------------------------------------------------
# filename = img_15_11_17.png, label = BODY, i = 2, j = 7, Max coeff. = 0.7532694039405058
# ----------------------------------------------------------
# filename = img_15_12_17.png, label = BODY, i = 2, j = 15, Max coeff. = 0.8557900275892836
# ----------------------------------------------------------
# filename = img_15_13_10.png, label = APPL, i = 1, j = 2, Max coeff. = 0.9097922304498626
# ----------------------------------------------------------
# filename = img_15_13_17.png, label = BODY, i = 2, j = 4, Max coeff. = 0.7027618886097131
# ----------------------------------------------------------
# filename = img_15_14_14.png, label = HEAD, i = 3, j = 1, Max coeff. = 0.5558073646677991
# ----------------------------------------------------------
# filename = img_15_14_15.png, label = BODY, i = 2, j = 3, Max coeff. = 0.9338238994052276
# ----------------------------------------------------------
# filename = img_15_14_16.png, label = BODY, i = 2, j = 2, Max coeff. = 0.9305259755124705
# ----------------------------------------------------------
# filename = img_15_14_17.png, label = BODY, i = 2, j = 14, Max coeff. = 0.919597441200552
# ----------------------------------------------------------
# ========================================================================================
# filename = img_16_09_15.png, label = BODY, i = 2, j = 10, Max coeff. = 0.6762346039762983
# ----------------------------------------------------------
# filename = img_16_09_16.png, label = BODY, i = 2, j = 15, Max coeff. = 0.41183799699749857
# ----------------------------------------------------------
# filename = img_16_09_17.png, label = BODY, i = 2, j = 4, Max coeff. = 0.7389232236837486
# ----------------------------------------------------------
# filename = img_16_10_17.png, label = BODY, i = 2, j = 2, Max coeff. = 0.6369767827640681
# ----------------------------------------------------------
# filename = img_16_11_17.png, label = BODY, i = 2, j = 1, Max coeff. = 0.49953981116787965
# ----------------------------------------------------------
# filename = img_16_12_17.png, label = HEAD, i = 3, j = 4, Max coeff. = 0.7154515870829816
# ----------------------------------------------------------
# filename = img_16_13_17.png, label = BODY, i = 2, j = 17, Max coeff. = 0.5991117597048199
# ----------------------------------------------------------
# filename = img_16_14_17.png, label = APPL, i = 1, j = 2, Max coeff. = 0.894231984378656
# ----------------------------------------------------------
# ========================================================================================

# %% [markdown]
# # Evaluation**

# %%
folder_path = "img_probe_labeled"
labels = [str(i) for i in range(4)]
label_str = ['BG', 'APPL', 'BODY', 'HEAD']

threshold = -1
hist_all_label, img_all_label = calc_all_hist()

# array of labels
predicted = []
ground_truth = []

for label in labels:
    probe_folder_path = f"{folder_path}/{label}/"
    for filename in os.listdir(probe_folder_path):
        img = cv2.imread(probe_folder_path + filename)
        img_label, img_no, coeff = predict_img_label(img, hist_all_label, threshold)
        
        ground_truth.append(int(label))
        predicted.append(img_label)

# %% [markdown]
# ## Confusion Matrix

# %%
import itertools
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#         print("Normalized confusion matrix")
#     else:
#         print('Confusion matrix, without normalization')

#     print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
def show_conf_matrix(y_test, y_pred, labels):
    # Compute confusion matrix
    cnf_matrix = confusion_matrix(y_test, y_pred)
    np.set_printoptions(precision=2)

    # Plot non-normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=labels,
                          title='Confusion matrix, without normalization')

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=labels, normalize=True,
                          title='Normalized confusion matrix')

    plt.show()

# %%
def show_clf_report(y_test, y_pred, labels):
    print(classification_report(y_test, y_pred, target_names=labels))

# %%
show_conf_matrix(ground_truth, predicted, label_str)
show_clf_report(ground_truth, predicted, label_str)
# Out:
#               precision    recall  f1-score   support
#
#           BG       1.00      1.00      1.00      1691
#         APPL       1.00      0.94      0.97        18
#         BODY       0.97      0.97      0.97       231
#         HEAD       0.88      0.72      0.79        29
#
#     accuracy                           0.99      1969
#    macro avg       0.96      0.91      0.93      1969
# weighted avg       0.99      0.99      0.99      1969

# %% [markdown]
# # Test

# %%
img_no = 17
img_filename = f"img_17_05_13.png"

folder_path = f"img_probe/img_{img_no}"
img_path = f"{folder_path}/{img_filename}"

img_i = cv2.imread(img_path)
img_i = crop_img(img_i)
hist_i = calc_hist(img_i)

hist_all_label, img_all_label = calc_all_hist()

x = 0
y = 0

sum_diff = 0
for chan in range(3):
    diff = cv2.compareHist(hist_i[chan], hist_all_label[x][y][chan], cv2.HISTCMP_CORREL)
    print(diff)
    sum_diff += diff
print('--------------------')
print(sum_diff/3)
    
# plot histograms and show images
plot_hist(hist_i)
plot_hist(hist_all_label[x][y])

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(5,12))
axes[0].imshow(img_i[::,::,::-1])
axes[1].imshow(img_all_label[x][y][::,::,::-1])
plt.show()
plt.close()
# Out:
# 0.3362410525440464
# 0.31744817427048777
# 0.2888500826943901
# --------------------
# 0.3141797698363081
