# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
def open_img(img_path):
    img = cv2.imread(img_path)
    
    (left, upper, right, lower) = (572, 271, 1330, 940)
    img_cropped = img[upper:lower, left:right]
    
    return img_cropped

# %%
def crop_img(img):
    (upper_t, lower_t, left_t, right_t) = (6, 34, 6, 34)
    img = img[upper_t:lower_t, left_t:right_t]
    
    return img

# %% [markdown]
# # Histogram methods

# %%
def calc_hist(img):
    img = img[upper_t:lower_t, left_t:right_t]
    
    chans = cv2.split(img)
    colors = ("b", "g", "r")
    
#     plt.figure()
    
    hist_arr = []
#     fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))
    
    # loop over the image channels
    for (chan, color) in zip(chans, colors):
#         plt.title("'Flattened' Color Histogram")
#         plt.xlabel("Bins")
#         plt.ylabel("# of Pixels")
        
        hist = cv2.calcHist([chan], [0], None, [128], [0, 256])
        norm_hist = cv2.normalize(hist, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
        hist_arr.append(norm_hist)
        
        # plot the histogram
#         axes[0].plot(norm_hist, color = color)
#         axes[0].set_xlim([0, 128])
    
#     axes[1].imshow(img[::,::,::-1])
#     plt.show()    
#     plt.close()
    
    return hist_arr

# %%
def plot_hist(hist):
    plt.title("'Flattened' Color Histogram")
    plt.xlabel("Bins")
    plt.ylabel("# of Pixels")
    
    chans = (0, 1, 2)
    colors = ("b", "g", "r")
    for (chan, color) in zip(chans, colors):
        plt.plot(hist[chan], color=color)
    
    plt.show()
    plt.close()

# %%
def calc_all_hist():
    hist_all_label = []
    img_all_label = []
    
    labeled_folder_path = "img_gallery"
    labels = [str(i) for i in range(4)]
    label_str = ['BG', 'APPL', 'BODY', 'HEAD']
    n_label = int(labels[-1]) + 1
    
    for label in labels:
        labeled_path = f"{labeled_folder_path}/{label}/"

        hist_label = []        
        img_label = []
        for filename in os.listdir(labeled_path):
#             print(labeled_path + filename)
            img = cv2.imread(labeled_path + filename)
            img_crp = crop_img(img)
            
            hist_img = calc_hist(img_crp)
            hist_label.append(hist_img)
            img_label.append(img_crp)
        hist_all_label.append(hist_label)
        img_all_label.append(img_label)
        
    return hist_all_label, img_all_label

# %% [markdown]
# # Preprocessing methods

# %%
def preprocessing(img):
    bg = open_img("img_raw/bg.png")
    
    # background subtraction
    img_sub = cv2.subtract(img, bg)
    
    # masking the image with the background
    img_gray = cv2.cvtColor(img_sub, cv2.COLOR_BGR2GRAY)
    ret,thresh1 = cv2.threshold(img_gray,5,255,cv2.THRESH_BINARY)

    kernel = np.ones((3,3),np.uint8)
    erosion = cv2.erode(thresh1,kernel,iterations = 2)
    dilation = cv2.dilate(erosion,kernel,iterations = 2)
    
    img_masked = cv2.bitwise_and(img, img, mask=dilation)
    
    return img_masked

# %%
def separate_img_to_tiles(img, image_no, out_folder):
    nrows = 15
    ncols = 17
    img_tiles = []

    size = 40
    w_start = 35
    h_start = 31

    y_start = h_start
    for i in range(nrows):
        if(i%2==0):
            y_end = y_start + size
        elif(i%2==1):
            y_end = y_start + (size+1)

        img_row = []
        x_start = w_start
        for j in range(ncols):
            if(j%2==0):
                x_end = x_start + (size+1)
            elif(j%2==1):
                x_end = x_start + size
            
            img_i = img[y_start:y_start+size, x_start:x_start+size]
            img_row.append(img_i)
            
            dir_path = f"{out_folder}/img_{image_no}"
            if(not os.path.exists(dir_path)):
                os.mkdir(dir_path)
            
            first_digit = str(i+1)
            second_digit = str(j+1)
            if(i+1<10):
                first_digit = f"0{first_digit}"
            if(j+1<10):
                second_digit = f"0{second_digit}"
                
            img_no = str(image_no)
            if(image_no<10):
                img_no = f"0{image_no}"

            cv2.imwrite(f"{dir_path}/img_{img_no}_{first_digit}_{second_digit}.png", img_i)
            
            # set the rightmost x-coordinate to be the new x_start
            x_start = x_end
            
        # set the bottommost y-coordinate to be the new y_start
        y_start = y_end
        
        img_tiles.append(img_row)
    
    return img_tiles

# %%
def segmentation(image_no, in_folder, out_folder):
    img_path = f"{in_folder}/{image_no}.png"
    img = open_img(img_path)    
    img_pp = preprocessing(img)
    img_tiles = separate_img_to_tiles(img_pp, image_no, out_folder)
        
    return img_tiles

# %% [markdown]
# # Prediction method

# %%
def predict_img_label(img, hist_all_label, threshold):
    img = crop_img(img)
    hist_img = calc_hist(img)
    
    threshold_bg = 0.9
    threshold_0 = threshold
    
    matched_i = -1
    matched_j = -1
    max_coeff = -1
    
    for i in range(n_label):
        for j in range(len(hist_all_label[i])):
            sum_diff = 0
            diffs = []
            for chan in range(3):
                diff = cv2.compareHist(hist_img[chan], hist_all_label[i][j][chan], cv2.HISTCMP_CORREL)
                sum_diff += diff
                diffs.append(diff)

            avg_diff = sum_diff/3
            to_print = False
            
            threshold_0 = threshold_bg if(i==0) else threshold
                
            if(avg_diff > threshold_0):
                to_print = True
                for k in range(3):
                    if(diffs[k]<threshold_0):
                        to_print = False

            if(to_print):
                if(avg_diff>max_coeff):
                    max_coeff = avg_diff
                    matched_i = i
                    matched_j = j
    
    if(max_coeff!=-1):
        return matched_i, matched_j, max_coeff
    
    return 0, -1, 0

# %% [markdown]
# # Executions

# %%
image_no = 11
bg = open_img("img_raw/bg.png")
img1 = open_img(f"img_raw/{image_no}.png")

bg_gray = cv2.cvtColor(bg, cv2.COLOR_BGR2GRAY)
img1_gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# %%
for i in range(1,108):
    segmentation(i, "img_raw", "img_proc")

# %%
for i in range(18):
    segmentation(i, "img_probe", "img_probe")

# %% [markdown]
# ## Demo

# %%
labeled_folder_path = "img_gallery"
labels = [str(i) for i in range(4)]
label_str = ['BG', 'APPL', 'BODY', 'HEAD']
n_label = int(labels[-1]) + 1

(upper_t, lower_t, left_t, right_t) = (6, 34, 6, 34)

# %%
sample_folder_path = "img_probe"
subfolder_path = [f"{sample_folder_path}/img_{i}/" for i in range(17)]

threshold = -1
hist_all_label = []
img_all_label = []
hist_all_label, img_all_label = calc_all_hist()

for path in subfolder_path:
    for filename in os.listdir(path):
        img = cv2.imread(path + filename)
        img = crop_img(img)
        
        img_label, img_no, max_coeff = predict_img_label(img, hist_all_label, threshold)
        
        if(img_label!=-1 and img_label!=0):
            fig, axes = plt.subplots(ncols=2, nrows=1)
            axes[0].imshow(img[::,::,::-1])
            axes[1].imshow(img_all_label[img_label][img_no][::,::,::-1])
            plt.show()
            plt.close()
            print(f"filename = {filename}, label = {label_str[img_label]}, i = {img_label}, j = {img_no}, Max coeff. = {max_coeff}")
            print('----------------------------------------------------------')
    print('========================================================================================')
# Out:
# filename = img_00_02_06.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# filename = img_00_05_06.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.7187937863298067
# ----------------------------------------------------------
# filename = img_00_06_06.png, label = BODY, i = 2, j = 3, Max coeff. = 0.5360373733271128
# ----------------------------------------------------------
# filename = img_00_07_06.png, label = BODY, i = 2, j = 1, Max coeff. = 0.6170213072989343
# ----------------------------------------------------------
# filename = img_00_08_06.png, label = BODY, i = 2, j = 5, Max coeff. = 0.9723521743720189
# ----------------------------------------------------------
# filename = img_00_09_06.png, label = BODY, i = 2, j = 14, Max coeff. = 0.4019304456253643
# ----------------------------------------------------------
# filename = img_00_10_06.png, label = BODY, i = 2, j = 4, Max coeff. = 0.9397093432760876
# ----------------------------------------------------------
# filename = img_00_10_07.png, label = BODY, i = 2, j = 4, Max coeff. = 0.0923964227020213
# ----------------------------------------------------------
# filename = img_00_10_08.png, label = BODY, i = 2, j = 15, Max coeff. = 0.9724397725361439
# ----------------------------------------------------------
# filename = img_00_10_09.png, label = BODY, i = 2, j = 10, Max coeff. = 0.2213996039789691
# ----------------------------------------------------------
# filename = img_00_10_10.png, label = BODY, i = 2, j = 7, Max coeff. = 0.8430689087036752
# ----------------------------------------------------------
# filename = img_00_10_11.png, label = BODY, i = 2, j = 16, Max coeff. = 0.6897659615424149
# ----------------------------------------------------------
# filename = img_00_10_12.png, label = BODY, i = 2, j = 18, Max coeff. = 0.7275349645795058
# ----------------------------------------------------------
# filename = img_00_10_13.png, label = BODY, i = 2, j = 6, Max coeff. = 0.9599490302591724
# ----------------------------------------------------------
# filename = img_00_10_14.png, label = BODY, i = 2, j = 17, Max coeff. = 0.27950001115162004
# ----------------------------------------------------------
# filename = img_00_10_15.png, label = BODY, i = 2, j = 11, Max coeff. = 0.9709226197729374
# ----------------------------------------------------------
# filename = img_0_02_06.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# filename = img_0_05_06.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.7187937863298067
# ----------------------------------------------------------
# filename = img_0_06_06.png, label = BODY, i = 2, j = 3, Max coeff. = 0.5360373733271128
# ----------------------------------------------------------
# filename = img_0_07_06.png, label = BODY, i = 2, j = 1, Max coeff. = 0.6170213072989343
# ----------------------------------------------------------
# filename = img_0_08_06.png, label = BODY, i = 2, j = 5, Max coeff. = 0.9723521743720189
# ----------------------------------------------------------
# filename = img_0_09_06.png, label = BODY, i = 2, j = 14, Max coeff. = 0.4019304456253643
# ----------------------------------------------------------
# filename = img_0_10_06.png, label = BODY, i = 2, j = 4, Max coeff. = 0.9397093432760876
# ----------------------------------------------------------
# filename = img_0_10_07.png, label = BODY, i = 2, j = 4, Max coeff. = 0.0923964227020213
# ----------------------------------------------------------
# filename = img_0_10_08.png, label = BODY, i = 2, j = 15, Max coeff. = 0.9724397725361439
# ----------------------------------------------------------
# filename = img_0_10_09.png, label = BODY, i = 2, j = 10, Max coeff. = 0.2213996039789691
# ----------------------------------------------------------
# filename = img_0_10_10.png, label = BODY, i = 2, j = 7, Max coeff. = 0.8430689087036752
# ----------------------------------------------------------
# filename = img_0_10_11.png, label = BODY, i = 2, j = 16, Max coeff. = 0.6897659615424149
# ----------------------------------------------------------
# filename = img_0_10_12.png, label = BODY, i = 2, j = 18, Max coeff. = 0.7275349645795058
# ----------------------------------------------------------
# filename = img_0_10_13.png, label = BODY, i = 2, j = 6, Max coeff. = 0.9599490302591724
# ----------------------------------------------------------
# filename = img_0_10_14.png, label = BODY, i = 2, j = 17, Max coeff. = 0.27950001115162004
# ----------------------------------------------------------
# filename = img_0_10_15.png, label = BODY, i = 2, j = 11, Max coeff. = 0.9709226197729374
# ----------------------------------------------------------
# ========================================================================================
# filename = img_01_02_02.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# filename = img_01_02_03.png, label = BODY, i = 2, j = 3, Max coeff. = 0.8112987809471247
# ----------------------------------------------------------
# filename = img_01_02_04.png, label = BODY, i = 2, j = 1, Max coeff. = 0.6785297160025587
# ----------------------------------------------------------
# filename = img_01_02_05.png, label = BODY, i = 2, j = 5, Max coeff. = 0.939040444577328
# ----------------------------------------------------------
# filename = img_01_03_03.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.5266335709498353
# ----------------------------------------------------------
# filename = img_01_03_05.png, label = BODY, i = 2, j = 14, Max coeff. = 0.3748649907794161
# ----------------------------------------------------------
# filename = img_01_04_03.png, label = HEAD, i = 3, j = 2, Max coeff. = 0.9782250345389474
# ----------------------------------------------------------
# filename = img_01_04_05.png, label = BODY, i = 2, j = 4, Max coeff. = 0.8028118795898301
# ----------------------------------------------------------
# filename = img_01_05_05.png, label = BODY, i = 2, j = 4, Max coeff. = 0.08139291514900777
# ----------------------------------------------------------
# filename = img_01_06_05.png, label = BODY, i = 2, j = 15, Max coeff. = 0.9230098843334136
# ----------------------------------------------------------
# filename = img_01_07_05.png, label = BODY, i = 2, j = 10, Max coeff. = 0.21225408125748343
# ----------------------------------------------------------
# filename = img_01_08_05.png, label = BODY, i = 2, j = 7, Max coeff. = 0.9118976995955063
# ----------------------------------------------------------
# filename = img_01_09_05.png, label = BODY, i = 2, j = 16, Max coeff. = 0.8701339220080948
# ----------------------------------------------------------
# filename = img_01_09_06.png, label = BODY, i = 2, j = 18, Max coeff. = 0.9169837328701546
# ----------------------------------------------------------
# filename = img_01_09_07.png, label = BODY, i = 2, j = 8, Max coeff. = 0.9125960344898467
# ----------------------------------------------------------
# filename = img_01_09_08.png, label = BODY, i = 2, j = 17, Max coeff. = 0.35659957084816724
# ----------------------------------------------------------
# filename = img_01_09_09.png, label = BODY, i = 2, j = 11, Max coeff. = 0.5461179200342711
# ----------------------------------------------------------
# filename = img_01_09_10.png, label = BODY, i = 2, j = 11, Max coeff. = 0.6014700980359741
# ----------------------------------------------------------
# filename = img_1_02_02.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# filename = img_1_02_03.png, label = BODY, i = 2, j = 3, Max coeff. = 0.8112987809471247
# ----------------------------------------------------------
# filename = img_1_02_04.png, label = BODY, i = 2, j = 1, Max coeff. = 0.6785297160025587
# ----------------------------------------------------------
# filename = img_1_02_05.png, label = BODY, i = 2, j = 5, Max coeff. = 0.939040444577328
# ----------------------------------------------------------
# filename = img_1_03_03.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.5266335709498353
# ----------------------------------------------------------
# filename = img_1_03_05.png, label = BODY, i = 2, j = 14, Max coeff. = 0.3748649907794161
# ----------------------------------------------------------
# filename = img_1_04_03.png, label = HEAD, i = 3, j = 2, Max coeff. = 0.9782250345389474
# ----------------------------------------------------------
# filename = img_1_04_05.png, label = BODY, i = 2, j = 4, Max coeff. = 0.8028118795898301
# ----------------------------------------------------------
# filename = img_1_05_05.png, label = BODY, i = 2, j = 4, Max coeff. = 0.08139291514900777
# ----------------------------------------------------------
# filename = img_1_06_05.png, label = BODY, i = 2, j = 15, Max coeff. = 0.9230098843334136
# ----------------------------------------------------------
# filename = img_1_07_05.png, label = BODY, i = 2, j = 10, Max coeff. = 0.21225408125748343
# ----------------------------------------------------------
# filename = img_1_08_05.png, label = BODY, i = 2, j = 7, Max coeff. = 0.9118976995955063
# ----------------------------------------------------------
# filename = img_1_09_05.png, label = BODY, i = 2, j = 16, Max coeff. = 0.8701339220080948
# ----------------------------------------------------------
# filename = img_1_09_06.png, label = BODY, i = 2, j = 18, Max coeff. = 0.9169837328701546
# ----------------------------------------------------------
# filename = img_1_09_07.png, label = BODY, i = 2, j = 8, Max coeff. = 0.9125960344898467
# ----------------------------------------------------------
# filename = img_1_09_08.png, label = BODY, i = 2, j = 17, Max coeff. = 0.35659957084816724
# ----------------------------------------------------------
# filename = img_1_09_09.png, label = BODY, i = 2, j = 11, Max coeff. = 0.5461179200342711
# ----------------------------------------------------------
# filename = img_1_09_10.png, label = BODY, i = 2, j = 11, Max coeff. = 0.6014700980359741
# ----------------------------------------------------------
# ========================================================================================
# filename = img_02_07_11.png, label = BODY, i = 2, j = 12, Max coeff. = 0.932266294709216
# ----------------------------------------------------------
# filename = img_02_08_02.png, label = BODY, i = 2, j = 4, Max coeff. = 0.566215085293129
# ----------------------------------------------------------
# filename = img_02_08_03.png, label = BODY, i = 2, j = 15, Max coeff. = 0.09441319214464443
# ----------------------------------------------------------
# filename = img_02_08_04.png, label = BODY, i = 2, j = 10, Max coeff. = 0.7145839789693292
# ----------------------------------------------------------
# filename = img_02_08_05.png, label = BODY, i = 2, j = 7, Max coeff. = 0.30090088205257515
# ----------------------------------------------------------
# filename = img_02_08_06.png, label = BODY, i = 2, j = 9, Max coeff. = 0.8521523901837561
# ----------------------------------------------------------
# filename = img_02_08_07.png, label = BODY, i = 2, j = 16, Max coeff. = 0.5953891355540364
# ----------------------------------------------------------
# filename = img_02_08_08.png, label = BODY, i = 2, j = 0, Max coeff. = 0.8523637673731713
# ----------------------------------------------------------
# filename = img_02_08_09.png, label = BODY, i = 2, j = 6, Max coeff. = 0.651834274285417
# ----------------------------------------------------------
# filename = img_02_08_10.png, label = BODY, i = 2, j = 17, Max coeff. = 0.3921290542567035
# ----------------------------------------------------------
# filename = img_02_09_02.png, label = BODY, i = 2, j = 14, Max coeff. = 0.4129927222490495
# ----------------------------------------------------------
# filename = img_02_09_10.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# filename = img_02_10_02.png, label = BODY, i = 2, j = 5, Max coeff. = 0.991837036963051
# ----------------------------------------------------------
# filename = img_02_11_02.png, label = BODY, i = 2, j = 1, Max coeff. = 0.5027759936162582
# ----------------------------------------------------------
# filename = img_02_11_03.png, label = BODY, i = 2, j = 3, Max coeff. = 0.7253953642038108
# ----------------------------------------------------------
# filename = img_02_11_04.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.5761646849893217
# ----------------------------------------------------------
# filename = img_02_11_05.png, label = HEAD, i = 3, j = 0, Max coeff. = 0.7533193373733528
# ----------------------------------------------------------
# filename = img_2_07_11.png, label = BODY, i = 2, j = 12, Max coeff. = 0.932266294709216
# ----------------------------------------------------------
# filename = img_2_08_02.png, label = BODY, i = 2, j = 4, Max coeff. = 0.566215085293129
# ----------------------------------------------------------
# filename = img_2_08_03.png, label = BODY, i = 2, j = 15, Max coeff. = 0.09441319214464443
# ----------------------------------------------------------
# filename = img_2_08_04.png, label = BODY, i = 2, j = 10, Max coeff. = 0.7145839789693292
# ----------------------------------------------------------
# filename = img_2_08_05.png, label = BODY, i = 2, j = 7, Max coeff. = 0.30090088205257515
# ----------------------------------------------------------
# filename = img_2_08_06.png, label = BODY, i = 2, j = 9, Max coeff. = 0.8521523901837561
# ----------------------------------------------------------
# filename = img_2_08_07.png, label = BODY, i = 2, j = 16, Max coeff. = 0.5953891355540364
# ----------------------------------------------------------
# filename = img_2_08_08.png, label = BODY, i = 2, j = 0, Max coeff. = 0.8523637673731713
# ----------------------------------------------------------
# filename = img_2_08_09.png, label = BODY, i = 2, j = 6, Max coeff. = 0.651834274285417
# ----------------------------------------------------------
# filename = img_2_08_10.png, label = BODY, i = 2, j = 17, Max coeff. = 0.3921290542567035
# ----------------------------------------------------------
# filename = img_2_09_02.png, label = BODY, i = 2, j = 14, Max coeff. = 0.4129927222490495
# ----------------------------------------------------------
# filename = img_2_09_10.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# filename = img_2_10_02.png, label = BODY, i = 2, j = 5, Max coeff. = 0.991837036963051
# ----------------------------------------------------------
# filename = img_2_11_02.png, label = BODY, i = 2, j = 1, Max coeff. = 0.5027759936162582
# ----------------------------------------------------------
# filename = img_2_11_03.png, label = BODY, i = 2, j = 3, Max coeff. = 0.7253953642038108
# ----------------------------------------------------------
# filename = img_2_11_04.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.5761646849893217
# ----------------------------------------------------------
# filename = img_2_11_05.png, label = HEAD, i = 3, j = 0, Max coeff. = 0.7533193373733528
# ----------------------------------------------------------
# ========================================================================================
# filename = img_03_02_11.png, label = BODY, i = 2, j = 7, Max coeff. = 0.43788644317517106
# ----------------------------------------------------------
# filename = img_03_02_12.png, label = BODY, i = 2, j = 15, Max coeff. = 0.6841563043729937
# ----------------------------------------------------------
# filename = img_03_02_13.png, label = BODY, i = 2, j = 4, Max coeff. = 0.805229826313214
# ----------------------------------------------------------
# filename = img_03_02_14.png, label = BODY, i = 2, j = 14, Max coeff. = 0.5652784268770722
# ----------------------------------------------------------
# filename = img_03_02_15.png, label = BODY, i = 2, j = 1, Max coeff. = 0.5503577217731096
# ----------------------------------------------------------
# filename = img_03_03_11.png, label = BODY, i = 2, j = 16, Max coeff. = 0.5774170159470811
# ----------------------------------------------------------
# filename = img_03_03_15.png, label = HEAD, i = 3, j = 3, Max coeff. = 0.39197989994950455
# ----------------------------------------------------------
# filename = img_03_04_11.png, label = BODY, i = 2, j = 8, Max coeff. = 0.8222038013874166
# ----------------------------------------------------------
# filename = img_03_04_15.png, label = HEAD, i = 3, j = 1, Max coeff. = 0.8819318566832685
# ----------------------------------------------------------
# filename = img_03_05_11.png, label = BODY, i = 2, j = 6, Max coeff. = 0.07345310013109678
# ----------------------------------------------------------
# filename = img_03_06_04.png, label = APPL, i = 1, j = 6, Max coeff. = 0.9992086082323003
# ----------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-74ab070d3463> in <module>
#      18             axes[0].imshow(img[::,::,::-1])
#      19             axes[1].imshow(img_all_label[img_label][img_no][::,::,::-1])
# ---> 20             plt.show()
#      21             plt.close()
#      22             print(f"filename = {filename}, label = {label_str[img_label]}, i = {img_label}, j = {img_no}, Max coeff. = {max_coeff}")
#
# c:\python37\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# c:\python37\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39             display(
#      40                 figure_manager.canvas.figure,
# ---> 41                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      42             )
#      43     finally:
#
# c:\python37\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     177         # the background is transparent
#     178         ticksLight = _is_light([label.get_color()
# --> 179                                 for axes in fig.axes
#     180                                 for axis in (axes.xaxis, axes.yaxis)
#     181                                 for label in axis.get_ticklabels()])
#
# c:\python37\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     179                                 for axes in fig.axes
#     180                                 for axis in (axes.xaxis, axes.yaxis)
# --> 181                                 for label in axis.get_ticklabels()])
#     182         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     183             # there are one or more tick labels, all with the same lightness
#
# c:\python37\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1253         if minor:
#    1254             return self.get_minorticklabels()
# -> 1255         return self.get_majorticklabels()
#    1256
#    1257     def get_majorticklines(self):
#
# c:\python37\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1205     def get_majorticklabels(self):
#    1206         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1207         ticks = self.get_major_ticks()
#    1208         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1209         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# c:\python37\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1380         while len(self.majorTicks) < numticks:
#    1381             # Update the new tick label properties from the old.
# -> 1382             tick = self._get_tick(major=True)
#    1383             self.majorTicks.append(tick)
#    1384             self._copy_tick_props(self.majorTicks[0], tick)
#
# c:\python37\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2014         else:
#    2015             tick_kw = self._minor_tick_kw
# -> 2016         return XTick(self.axes, 0, major=major, **tick_kw)
#    2017
#    2018     def set_label_position(self, position):
#
# c:\python37\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     420             xdata=[0], ydata=[0],
#     421             transform=self.axes.get_xaxis_transform(which="tick1"),
# --> 422             marker=self._tickmarkers[0],
#     423         )
#     424         self.tick2line.set(
#
# c:\python37\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1111         if move_color_to_start:
#    1112             kwargs = {"color": kwargs.pop("color"), **kwargs}
# -> 1113         return self.update(kwargs)
#    1114
#    1115     def findobj(self, match=None, include_self=True):
#
# c:\python37\lib\site-packages\matplotlib\artist.py in update(self, props)
#     996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
# --> 998                     ret.append(func(v))
#     999         if ret:
#    1000             self.pchanged()
#
# c:\python37\lib\site-packages\matplotlib\lines.py in set_marker(self, marker)
#    1155             arguments.
#    1156         """
# -> 1157         self._marker.set_marker(marker)
#    1158         self.stale = True
#    1159
#
# c:\python37\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     311         if not isinstance(marker, MarkerStyle):
#     312             self._marker = marker
# --> 313             self._recache()
#     314
#     315     def get_path(self):
#
# c:\python37\lib\site-packages\matplotlib\markers.py in _recache(self)
#     239         self._capstyle = 'butt'
#     240         self._filled = True
# --> 241         self._marker_function()
#     242
#     243     def __bool__(self):
#
# c:\python37\lib\site-packages\matplotlib\markers.py in _set_tickdown(self)
#     752
#     753     def _set_tickdown(self):
# --> 754         self._transform = Affine2D().scale(1.0, -1.0)
#     755         self._snap_threshold = 1.0
#     756         self._filled = False
#
# c:\python37\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1843         if matrix is None:
#    1844             # A bit faster than np.identity(3).
# -> 1845             matrix = IdentityTransform._mtx.copy()
#    1846         self._mtx = matrix.copy()
#    1847         self._invalid = 0
#
# KeyboardInterrupt:

# %% [markdown]
# # Evaluation**

# %%
folder_path = "img_probe_labeled"
labels = [str(i) for i in range(4)]
label_str = ['BG', 'APPL', 'BODY', 'HEAD']

threshold = -1
hist_all_label, img_all_label = calc_all_hist()

# array of labels
predicted = []
ground_truth = []

for label in labels:
    probe_folder_path = f"{folder_path}/{label}/"
    for filename in os.listdir(probe_folder_path):
        img = cv2.imread(probe_folder_path + filename)
        img_label, img_no, coeff = predict_img_label(img, hist_all_label, threshold)
        
        ground_truth.append(int(label))
        predicted.append(img_label)

# %% [markdown]
# ## Confusion Matrix

# %%
import itertools
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#         print("Normalized confusion matrix")
#     else:
#         print('Confusion matrix, without normalization')

#     print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
def show_conf_matrix(y_test, y_pred, labels):
    # Compute confusion matrix
    cnf_matrix = confusion_matrix(y_test, y_pred)
    np.set_printoptions(precision=2)

    # Plot non-normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=labels,
                          title='Confusion matrix, without normalization')

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=labels, normalize=True,
                          title='Normalized confusion matrix')

    plt.show()

# %%
def show_clf_report(y_test, y_pred, labels):
    print(classification_report(y_test, y_pred, target_names=labels))

# %%
show_conf_matrix(ground_truth, predicted, label_str)
show_clf_report(ground_truth, predicted, label_str)
# Out:
#               precision    recall  f1-score   support
#
#           BG       0.99      1.00      1.00      1361
#         APPL       1.00      0.92      0.96       104
#         BODY       0.99      0.95      0.97       289
#         HEAD       0.93      1.00      0.96       110
#
#     accuracy                           0.99      1864
#    macro avg       0.98      0.97      0.97      1864
# weighted avg       0.99      0.99      0.99      1864

# %% [markdown]
# # Test

# %%
img_no = 17
img_filename = f"img_17_05_13.png"

folder_path = f"img_probe/img_{img_no}"
img_path = f"{folder_path}/{img_filename}"

img_i = cv2.imread(img_path)
img_i = crop_img(img_i)
hist_i = calc_hist(img_i)

hist_all_label, img_all_label = calc_all_hist()

x = 2
y = 0

sum_diff = 0
for chan in range(3):
    diff = cv2.compareHist(hist_i[chan], hist_all_label[x][y][chan], cv2.HISTCMP_CORREL)
    print(diff)
    sum_diff += diff
print('--------------------')
print(sum_diff/3)
    
# plot histograms and show images
plot_hist(hist_i)
plot_hist(hist_all_label[x][y])

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(5,12))
axes[0].imshow(img_i[::,::,::-1])
axes[1].imshow(img_all_label[x][y][::,::,::-1])
plt.show()
plt.close()
# Out:
# 0.001415675797151551
# 0.001218470263920406
# 0.026352294653707208
# --------------------
# 0.009662146904926389
